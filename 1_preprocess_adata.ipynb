# %%
import scanpy as sc
import os
import re
import scipy as scp
import pandas as pd
import scvelo as scv

# %%
#Read the downloaded output files from the folders
adataNames = os.listdir('./adataObjs/')
adataList = []
for aN in adataNames:
    adataList.append(sc.read_h5ad('./adataObjs/'+aN))
adataList
# Out:
# [AnnData object with n_obs × n_vars = 138540 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116408 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116486 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 159643 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144376 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 106378 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 134343 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 111044 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 153254 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116974 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 145744 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 141065 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135125 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 134412 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151317 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 101393 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 129784 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 188624 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144137 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 209885 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 111928 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144621 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 114267 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 132227 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 109797 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 107397 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 156809 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 157825 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 118347 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 152265 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 108733 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143497 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 109151 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 118370 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143505 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 118165 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 114938 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143684 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 161416 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 191856 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 147851 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151286 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 103316 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 133224 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 155543 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 141467 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 111805 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144706 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 156220 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 145707 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 192529 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 106611 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 103860 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 140575 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 152396 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 158622 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135299 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 105084 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 157231 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 147738 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 191622 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 138178 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151624 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151948 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151073 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 140444 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 154064 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 132910 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 154833 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 193651 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144124 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116748 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 105130 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 134420 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 132825 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 158323 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 138483 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135058 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 159465 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 154041 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 104209 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151079 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 109226 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135753 × 60623
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143997 × 60623
#      layers: 'spliced', 'unspliced']

# %%
samples = []
for an in adataNames:
    samples.append(re.search('S.*[0-9]_',an).group()[:-1])
#for z in zip(adataNames,samples):
    #print(z)

# %%
for i,adata in enumerate(adataList):
    adata.obs["folder"] = samples[i]
adataList
# Out:
# [AnnData object with n_obs × n_vars = 138540 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116408 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116486 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 159643 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144376 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 106378 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 134343 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 111044 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 153254 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116974 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 145744 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 141065 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135125 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 134412 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151317 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 101393 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 129784 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 188624 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144137 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 209885 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 111928 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144621 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 114267 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 132227 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 109797 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 107397 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 156809 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 157825 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 118347 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 152265 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 108733 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143497 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 109151 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 118370 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143505 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 118165 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 114938 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143684 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 161416 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 191856 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 147851 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151286 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 103316 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 133224 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 155543 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 141467 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 111805 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144706 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 156220 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 145707 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 192529 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 106611 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 103860 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 140575 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 152396 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 158622 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135299 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 105084 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 157231 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 147738 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 191622 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 138178 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151624 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151948 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151073 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 140444 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 154064 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 132910 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 154833 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 193651 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 144124 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 116748 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 105130 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 134420 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 132825 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 158323 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 138483 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135058 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 159465 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 154041 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 104209 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 151079 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 109226 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 135753 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 143997 × 60623
#      obs: 'folder'
#      layers: 'spliced', 'unspliced']

# %%
# check if the barcodes are unique
uniqueCheck = []
for adata in adataList:
    uniqueCheck.append(len(set(adata.obs.index)) == len(adata.obs.index))
all(uniqueCheck)
# Out:
# True

# %%
#filter cells and genes
for adata in adataList:
    sc.pp.filter_cells(adata,min_genes=200)
    sc.pp.filter_genes(adata,min_cells=3)
adataList
# Out:
# [AnnData object with n_obs × n_vars = 3320 × 15465
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1834 × 13797
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2167 × 14809
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1904 × 15976
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 4270 × 16736
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1348 × 14027
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1396 × 15259
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2607 × 14042
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2570 × 16806
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2704 × 14853
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2748 × 15574
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 4256 × 16751
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1828 × 14022
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1395 × 15270
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2580 × 16795
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3329 × 14640
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3838 × 16267
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1943 × 15228
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 4264 × 16866
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 5314 × 16673
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2624 × 14062
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2745 × 15417
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2421 × 15245
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1833 × 13885
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2163 × 14121
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3390 × 15093
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1909 × 15908
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3442 × 15221
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2700 × 14993
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2233 × 16474
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2168 × 14018
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2276 × 15463
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3339 × 15139
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1824 × 14555
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2279 × 15448
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1823 × 13913
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2172 × 14808
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 4246 × 16823
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3127 × 15225
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1955 × 15188
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2237 × 16298
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2241 × 16329
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3293 × 14782
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3847 × 16286
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2778 × 16562
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2749 × 15309
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2424 × 15146
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2276 × 15539
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2779 × 16675
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 4244 × 16918
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1956 × 15324
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3024 × 14199
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3042 × 14068
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3329 × 15649
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2575 × 16702
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3239 × 15222
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1397 × 15330
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1349 × 13928
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1924 × 15831
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2572 × 16711
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1948 × 15217
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3325 × 15457
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2587 × 16650
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2235 × 16326
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2778 × 16548
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2280 × 15361
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1910 × 15811
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3848 × 16312
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2782 × 16518
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1949 × 15386
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2761 × 15436
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1826 × 14418
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1356 × 13952
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3843 × 16448
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3864 × 16267
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1915 × 15860
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3331 × 15428
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1398 × 15212
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3094 × 15336
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3021 × 15250
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 1348 × 13873
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2238 × 16390
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2614 × 13937
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 3324 × 15467
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced',
#  AnnData object with n_obs × n_vars = 2279 × 15380
#      obs: 'folder', 'n_genes'
#      var: 'n_cells'
#      layers: 'spliced', 'unspliced']

# %%
adata = adataList[0].concatenate(adataList[1:],join='outer')
adata
# Out:
# layers concatenation is not yet available for 'outer' intersection and will be ignored.
# AnnData object with n_obs × n_vars = 223413 × 22555
#     obs: 'batch', 'folder', 'n_genes'
#     var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3', 'n_cells-4', 'n_cells-5', 'n_cells-6', 'n_cells-7', 'n_cells-8', 'n_cells-9', 'n_cells-10', 'n_cells-11', 'n_cells-12', 'n_cells-13', 'n_cells-14', 'n_cells-15', 'n_cells-16', 'n_cells-17', 'n_cells-18', 'n_cells-19', 'n_cells-20', 'n_cells-21', 'n_cells-22', 'n_cells-23', 'n_cells-24', 'n_cells-25', 'n_cells-26', 'n_cells-27', 'n_cells-28', 'n_cells-29', 'n_cells-30', 'n_cells-31', 'n_cells-32', 'n_cells-33', 'n_cells-34', 'n_cells-35', 'n_cells-36', 'n_cells-37', 'n_cells-38', 'n_cells-39', 'n_cells-40', 'n_cells-41', 'n_cells-42', 'n_cells-43', 'n_cells-44', 'n_cells-45', 'n_cells-46', 'n_cells-47', 'n_cells-48', 'n_cells-49', 'n_cells-50', 'n_cells-51', 'n_cells-52', 'n_cells-53', 'n_cells-54', 'n_cells-55', 'n_cells-56', 'n_cells-57', 'n_cells-58', 'n_cells-59', 'n_cells-60', 'n_cells-61', 'n_cells-62', 'n_cells-63', 'n_cells-64', 'n_cells-65', 'n_cells-66', 'n_cells-67', 'n_cells-68', 'n_cells-69', 'n_cells-70', 'n_cells-71', 'n_cells-72', 'n_cells-73', 'n_cells-74', 'n_cells-75', 'n_cells-76', 'n_cells-77', 'n_cells-78', 'n_cells-79', 'n_cells-80', 'n_cells-81', 'n_cells-82', 'n_cells-83', 'n_cells-84'

# %%
obs = []
for barcode in adata.obs.index:
    obs.append(barcode)
len(obs) == len(set(obs))
# Out:
# True

# %%
#store spliced and unspliced for concatenation separately because it will get concat
s = []
u = []
for ad in adataList:
    s.append(scp.sparse.csr_matrix(ad.layers['spliced']))
    u.append(scp.sparse.csr_matrix(ad.layers['unspliced']))

# %%
#Convert the spliced and unspliced matrices to pandas dataframe
pdS = []
pdU = []
for i,sm in enumerate(s):
    pdS.append(pd.DataFrame(sm.toarray(),index=adataList[i].obs.index,columns=adataList[i].var.index))
for i,um in enumerate(u): 
    pdU.append(pd.DataFrame(um.toarray(),index=adataList[i].obs.index,columns=adataList[i].var.index))

# %%
#concatenate the data
pdSCon = pd.concat(pdS,sort=False)
pdUCon = pd.concat(pdU,sort=False)

# %%
# Rearrange the gene names (cols) to match with the adata concatenation
pdSCon = pdSCon.loc[:,adata.var.index]
pdUCon = pdUCon.loc[:,adata.var.index]
#fill na with 0
pdSCon.fillna(0,inplace=True)
pdUCon.fillna(0,inplace=True)

# %%
equal = 0
for i,val in enumerate(pdSCon.columns):
    if val == adata.var.index[i]:
        equal +=1
equal == len(pdSCon.columns)
# Out:
# True

# %%
adata.layers['spliced'] = scp.sparse.csr_matrix(pdSCon.values)
adata.layers['unspliced'] = scp.sparse.csr_matrix(pdUCon.values)

# %%
scv.utils.show_proportions(adata)
adata
# Out:
# Abundance of ['spliced', 'unspliced']: [0.77 0.23]
# AnnData object with n_obs × n_vars = 223413 × 22555
#     obs: 'batch', 'folder', 'n_genes'
#     var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3', 'n_cells-4', 'n_cells-5', 'n_cells-6', 'n_cells-7', 'n_cells-8', 'n_cells-9', 'n_cells-10', 'n_cells-11', 'n_cells-12', 'n_cells-13', 'n_cells-14', 'n_cells-15', 'n_cells-16', 'n_cells-17', 'n_cells-18', 'n_cells-19', 'n_cells-20', 'n_cells-21', 'n_cells-22', 'n_cells-23', 'n_cells-24', 'n_cells-25', 'n_cells-26', 'n_cells-27', 'n_cells-28', 'n_cells-29', 'n_cells-30', 'n_cells-31', 'n_cells-32', 'n_cells-33', 'n_cells-34', 'n_cells-35', 'n_cells-36', 'n_cells-37', 'n_cells-38', 'n_cells-39', 'n_cells-40', 'n_cells-41', 'n_cells-42', 'n_cells-43', 'n_cells-44', 'n_cells-45', 'n_cells-46', 'n_cells-47', 'n_cells-48', 'n_cells-49', 'n_cells-50', 'n_cells-51', 'n_cells-52', 'n_cells-53', 'n_cells-54', 'n_cells-55', 'n_cells-56', 'n_cells-57', 'n_cells-58', 'n_cells-59', 'n_cells-60', 'n_cells-61', 'n_cells-62', 'n_cells-63', 'n_cells-64', 'n_cells-65', 'n_cells-66', 'n_cells-67', 'n_cells-68', 'n_cells-69', 'n_cells-70', 'n_cells-71', 'n_cells-72', 'n_cells-73', 'n_cells-74', 'n_cells-75', 'n_cells-76', 'n_cells-77', 'n_cells-78', 'n_cells-79', 'n_cells-80', 'n_cells-81', 'n_cells-82', 'n_cells-83', 'n_cells-84'
#     layers: 'spliced', 'unspliced'

# %%
adata.obs.head()
# Out:
#                    batch   folder  n_genes
# AAACCTGAGCGATTCT-0     0  S4_L007     2596
# AAACCTGAGCTTTGGT-0     0  S4_L007      329
# AAACCTGAGGCCCTCA-0     0  S4_L007     2178
# AAACCTGAGTAGCCGA-0     0  S4_L007      253
# AAACCTGGTAGCGCTC-0     0  S4_L007      420

# %%
adata.var.head()
# Out:
#                     n_cells-0  n_cells-1  n_cells-2  n_cells-3  n_cells-4  \
# ENSG00000001460.18       89.0       32.0       55.0      105.0      177.0
# ENSG00000001461.17      405.0      181.0      231.0      369.0      635.0
# ENSG00000010072.16      244.0      198.0      142.0      290.0      331.0
# ENSG00000009780.15      123.0      124.0      131.0      119.0      343.0
# ENSG00000048707.15      218.0       61.0       88.0      126.0      196.0
#
#                     n_cells-5  n_cells-6  n_cells-7  n_cells-8  n_cells-9  \
# ENSG00000001460.18       41.0       58.0       50.0      179.0       78.0
# ENSG00000001461.17      229.0      382.0      212.0      645.0      264.0
# ENSG00000010072.16      210.0      330.0      148.0      359.0      144.0
# ENSG00000009780.15      135.0      233.0       55.0      301.0      114.0
# ENSG00000048707.15       80.0      126.0       74.0      187.0       80.0
#
#                        ...      n_cells-75  n_cells-76  n_cells-77  \
# ENSG00000001460.18     ...           112.0       101.0        56.0
# ENSG00000001461.17     ...           399.0       427.0       400.0
# ENSG00000010072.16     ...           296.0       241.0       319.0
# ENSG00000009780.15     ...           116.0        97.0       251.0
# ENSG00000048707.15     ...           130.0       224.0       123.0
#
#                     n_cells-78  n_cells-79  n_cells-80  n_cells-81  \
# ENSG00000001460.18        61.0        62.0        36.0       108.0
# ENSG00000001461.17       368.0       359.0       241.0       438.0
# ENSG00000010072.16       353.0       352.0       178.0       288.0
# ENSG00000009780.15       204.0       228.0       151.0       235.0
# ENSG00000048707.15        94.0       105.0        63.0       164.0
#
#                     n_cells-82  n_cells-83  n_cells-84
# ENSG00000001460.18        49.0        88.0        68.0
# ENSG00000001461.17       190.0       403.0       413.0
# ENSG00000010072.16       149.0       195.0       366.0
# ENSG00000009780.15        63.0        99.0       254.0
# ENSG00000048707.15        82.0       208.0       121.0
#
# [5 rows x 85 columns]

# %%
adata.obs.drop('batch',axis=1,inplace=True)
adata.obs.head()
# Out:
#                      folder  n_genes
# AAACCTGAGCGATTCT-0  S4_L007     2596
# AAACCTGAGCTTTGGT-0  S4_L007      329
# AAACCTGAGGCCCTCA-0  S4_L007     2178
# AAACCTGAGTAGCCGA-0  S4_L007      253
# AAACCTGGTAGCGCTC-0  S4_L007      420

# %%
#convert na to 0
adata.var.fillna(0,inplace=True)

# %%
df = pd.DataFrame(data=adata.var.apply(sum,1,result_type='reduce'),columns=['n_cells'])
df
# Out:
#                      n_cells
# ENSG00000001460.18    7252.0
# ENSG00000001461.17   31838.0
# ENSG00000010072.16   22712.0
# ENSG00000009780.15   15246.0
# ENSG00000048707.15   11175.0
# ENSG00000059588.10   14109.0
# ENSG00000041988.15   17368.0
# ENSG00000049245.13   73043.0
# ENSG00000052723.11   60322.0
# ENSG00000058799.15   22188.0
# ENSG00000060642.10   18859.0
# ENSG00000069424.15    9673.0
# ENSG00000074964.17    5560.0
# ENSG00000081870.11   87432.0
# ENSG00000083444.17   39605.0
# ENSG00000076321.11   13877.0
# ENSG00000069702.11    1063.0
# ENSG00000074800.16  180479.0
# ENSG00000097046.13   12540.0
# ENSG00000097096.9     7037.0
# ENSG00000031698.13  104264.0
# ENSG00000116128.11    4346.0
# ENSG00000116205.14    6010.0
# ENSG00000116209.12  124887.0
# ENSG00000116251.11   60890.0
# ENSG00000116455.14   16696.0
# ENSG00000116667.14    2166.0
# ENSG00000116670.15   70475.0
# ENSG00000116688.16   24551.0
# ENSG00000116691.11   30275.0
# ...                      ...
# ENSG00000134516.17     392.0
# ENSG00000255245.4        7.0
# ENSG00000241993.1        3.0
# ENSG00000241135.6        3.0
# ENSG00000158882.15     151.0
# ENSG00000234884.2        4.0
# ENSG00000234076.1      257.0
# ENSG00000261678.3      175.0
# ENSG00000179958.9      165.0
# ENSG00000227080.2        6.0
# ENSG00000254418.1      460.0
# ENSG00000102575.13     126.0
# ENSG00000271553.1      556.0
# ENSG00000223298.1      263.0
# ENSG00000231346.5      142.0
# ENSG00000143839.15      75.0
# ENSG00000174450.12      55.0
# ENSG00000244694.7        9.0
# ENSG00000262343.1       13.0
# ENSG00000239323.1       33.0
# ENSG00000161835.11       6.0
# ENSG00000173809.18     124.0
# ENSG00000237126.8       62.0
# ENSG00000236699.9       12.0
# ENSG00000242252.2      149.0
# ENSG00000242461.1       35.0
# ENSG00000231364.3       23.0
# ENSG00000288023.1      309.0
# ENSG00000211445.12   34066.0
# ENSG00000267547.1      631.0
#
# [22555 rows x 1 columns]

# %%
adata.var = df
adata.var.head()
# Out:
#                     n_cells
# ENSG00000001460.18   7252.0
# ENSG00000001461.17  31838.0
# ENSG00000010072.16  22712.0
# ENSG00000009780.15  15246.0
# ENSG00000048707.15  11175.0

# %%
print(adata)
print(adata.obs.head())
print(adata.var.head())
adata.layers['spliced']
# Out:
# AnnData object with n_obs × n_vars = 223413 × 22555
#     obs: 'folder', 'n_genes'
#     var: 'n_cells'
#     layers: 'spliced', 'unspliced'
#                      folder  n_genes
# AAACCTGAGCGATTCT-0  S4_L007     2596
# AAACCTGAGCTTTGGT-0  S4_L007      329
# AAACCTGAGGCCCTCA-0  S4_L007     2178
# AAACCTGAGTAGCCGA-0  S4_L007      253
# AAACCTGGTAGCGCTC-0  S4_L007      420
#                     n_cells
# ENSG00000001460.18   7252.0
# ENSG00000001461.17  31838.0
# ENSG00000010072.16  22712.0
# ENSG00000009780.15  15246.0
# ENSG00000048707.15  11175.0
# <223413x22555 sparse matrix of type '<class 'numpy.float32'>'
# 	with 396045101 stored elements in Compressed Sparse Row format>

# %%
adata.write('processed_adata.h5ad')
# Out:
# ... storing 'folder' as categorical
