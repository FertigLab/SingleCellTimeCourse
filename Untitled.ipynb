# %%
library(monocle)
# Out:
# Loading required package: Matrix
# Loading required package: Biobase
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following object is masked from ‘package:Matrix’:
#
#     which
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
# ...

# %%
load('ShortTimeCourse_cds.Rda')

# %%
ls()
cds.stc
# Out:
# [1] "cds.stc"
# CellDataSet (storageMode: environment)
# assayData: 33538 features, 23914 samples
#   element names: exprs
# protocolData: none
# phenoData
#   sampleNames: AAACCTGAGTTGTCGT-1_SCC1_CTX_R1
#     AAACCTGCACAGCGTC-1_SCC1_CTX_R1 ... TTTGTCAGTAGAGTGC-1_SCC25_PBS_R2
#     (23914 total)
#   varLabels: samples cell ... Size_Factor (5 total)
#   varMetadata: labelDescription
# featureData
#   featureNames: MIR1302.2HG FAM138A ... FAM231C (33538 total)
#   fvarLabels: gene_short_name feature
#   fvarMetadata: labelDescription
# experimentData: use 'experimentData(object)'
# Annotation:

# %%
cds.stc@phenoData@data
# Out:
#                                 samples                         cell  treatment
# AAACCTGAGTTGTCGT-1_SCC1_CTX_R1  AAACCTGAGTTGTCGT-1_SCC1_CTX_R1  SCC1  CTX
# AAACCTGCACAGCGTC-1_SCC1_CTX_R1  AAACCTGCACAGCGTC-1_SCC1_CTX_R1  SCC1  CTX
# AAACCTGGTACTTCTT-1_SCC1_CTX_R1  AAACCTGGTACTTCTT-1_SCC1_CTX_R1  SCC1  CTX
# AAAGATGGTGTGAATA-1_SCC1_CTX_R1  AAAGATGGTGTGAATA-1_SCC1_CTX_R1  SCC1  CTX
# AAAGCAAGTAGCTGCC-1_SCC1_CTX_R1  AAAGCAAGTAGCTGCC-1_SCC1_CTX_R1  SCC1  CTX
# AAAGTAGCATGCTGGC-1_SCC1_CTX_R1  AAAGTAGCATGCTGGC-1_SCC1_CTX_R1  SCC1  CTX
# AAAGTAGCATGGGACA-1_SCC1_CTX_R1  AAAGTAGCATGGGACA-1_SCC1_CTX_R1  SCC1  CTX
# AAAGTAGGTGGCAAAC-1_SCC1_CTX_R1  AAAGTAGGTGGCAAAC-1_SCC1_CTX_R1  SCC1  CTX
# AAATGCCTCGCCCTTA-1_SCC1_CTX_R1  AAATGCCTCGCCCTTA-1_SCC1_CTX_R1  SCC1  CTX
# AACACGTGTCCAGTTA-1_SCC1_CTX_R1  AACACGTGTCCAGTTA-1_SCC1_CTX_R1  SCC1  CTX
# AACCATGCAGCGTTCG-1_SCC1_CTX_R1  AACCATGCAGCGTTCG-1_SCC1_CTX_R1  SCC1  CTX
# AACGTTGCAAGGACTG-1_SCC1_CTX_R1  AACGTTGCAAGGACTG-1_SCC1_CTX_R1  SCC1  CTX
# ...
